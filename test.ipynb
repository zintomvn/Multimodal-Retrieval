# %%
# import os
# from langchain_openai import ChatOpenAI
# from dotenv import load_dotenv
# load_dotenv()

# %%
import dagshub

dagshub.init(repo_owner='DinhXuanKhuong', repo_name='my-first-repo', mlflow=True)
# Out:
# Initialized MLflow to track repo "DinhXuanKhuong/my-first-repo"
# Repository DinhXuanKhuong/my-first-repo initialized!

# %%
import mlflow
with mlflow.start_run():
  # Your training code here...
  mlflow.log_metric('accuracy', 42)
  mlflow.log_param('Param name', 'Value')
# Out:
# 🏃 View run treasured-goose-90 at: https://dagshub.com/DinhXuanKhuong/my-first-repo.mlflow/#/experiments/0/runs/c1effa76d2274a22a132f60bfc8e7eba
# 🧪 View experiment at: https://dagshub.com/DinhXuanKhuong/my-first-repo.mlflow/#/experiments/0

# %%
# llm = ChatOpenAI(
#     model="openai/gpt-oss-120b:free",
#     base_url="https://openrouter.ai/api/v1",
#     api_key=os.getenv("OPENROUTER_API_KEY"),
# )

# %%
# response = llm.invoke("Hãy giới thiệu bản thân trong 3 câu.")

# print(response.content)
# Out:
# Xin chào! Tôi là ChatGPT, một mô hình ngôn ngữ trí tuệ nhân tạo được phát triển bởi OpenAI, có khả năng hiểu và tạo ra văn bản đa dạng bằng nhiều ngôn ngữ. Tôi luôn sẵn sàng hỗ trợ bạn giải đáp thắc mắc, sáng tạo ý tưởng và cung cấp thông tin hữu ích trong mọi lĩnh vực.
