# %% [markdown]
# # Exp. 1 — Temporal Search
#
# This notebook compares ATS, Vortex, and DEV with GPT-4o, SigLIP2, and top-100 fixed. For each query it first calls `/api/retrieval/plan` once, verifies the GPT-4o plan, then runs all pending strategies sequentially so they share that cached plan. Completed strategy/query pairs are skipped; prior 504 pairs are retried.
#
# The default is a 10-query smoke test. Change `--limit 10` to `--limit 0` only after reviewing `smoke_test_10_summary.csv`.

# %%
# %run run_exp1_temporal_search.py --limit 10
# %run run_exp1_temporal_search.py --limit 0
# Out:
# PLAN 76/78 query-p3-33-kis: GPT-4o cached in 12054 ms
# ATS query-p3-33-kis: rank=None error=
# Vortex query-p3-33-kis: rank=40 error=
# DEV query-p3-33-kis: rank=91 error=
# PLAN 77/78 query-p3-35-qa: GPT-4o cached in 10690 ms
# ATS query-p3-35-qa: rank=3 error=
# Vortex query-p3-35-qa: rank=3 error=
# DEV query-p3-35-qa: rank=3 error=
# PLAN 78/78 query-p3-36-kis: GPT-4o cached in 15117 ms
# ATS query-p3-36-kis: rank=1 error=
# Vortex query-p3-36-kis: rank=1 error=
# DEV query-p3-36-kis: rank=1 error=
# [
#   {
#     "method": "ATS",
#     "temporal_strategy": "aithena_weighted_ats",
#     "queries": 78,
#     "R@1": 35.9,
#     "R@5": 56.41,
#     "R@10": 58.97,
#     "R@20": 64.1,
#     "R@50": 66.67,
#     "R@100": 67.95,
#     "exact_frame_hits": 1,
#     "sequence_frame_hits": 2,
#     "errors": 0,
#     "median_latency_ms": 9087.5
#   },
#   {
#     "method": "Vortex",
#     "temporal_strategy": "vortex_k_context",
#     "queries": 78,
#     "R@1": 34.62,
#     "R@5": 58.97,
# ...
